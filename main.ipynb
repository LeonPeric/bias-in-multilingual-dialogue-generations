# %%
from models import Model

# %%
model = Model("Aya", 512, 0.0, 1, 2)
# Out:
# c:\Users\leonp\anaconda3\Lib\site-packages\transformers\models\auto\auto_factory.py:468: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/11 [00:00<?, ?it/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu and disk.
# c:\Users\leonp\anaconda3\Lib\site-packages\transformers\models\auto\tokenization_auto.py:757: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(

# %%
# in case we want to model more chatbot like, see models.py
messages = [[{"role": "user", "content": "Hi! I am a man."}],[{"role": "user", "content": "Hoi! Ik ben een man."}]]

# %%
import pickle
with open("messages.pkl", "wb") as f:
    pickle.dump(messages, f)

# %%
with open("messages.pkl", "rb") as f:
    messages = pickle.load(f)

# %%
input_ids = model.prepare_input(messages)
# Out:
# No chat template is defined for this tokenizer - using a default chat template that implements the ChatML format (without BOS/EOS tokens!). If the default is not appropriate for your model, please set `tokenizer.chat_template` to an appropriate template. See https://huggingface.co/docs/transformers/main/chat_templating for more information.

# %%
results = model.generate(input_ids)

# %%
print(results)
# Out:
# ['Hello! How can I help you today?', 'Hallo. - Hallo. Hoe kan ik u helpen vandaag?']

# %%
# Llama: 1M26S
# Mistral: 4M14S
